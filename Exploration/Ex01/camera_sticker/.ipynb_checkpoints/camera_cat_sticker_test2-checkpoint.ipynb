# %%
# !pip install cmake opencv-python
# !conda install -y dlib

# %%
import cv2
import dlib

print(cv2.__version__)
print(dlib.__version__)
# Out:
# 4.12.0
# 20.0.0

# %%
# Step 2. 얼굴 검출 & 랜드마크 검출 하기

# %%
# 필요한 패키지 import 하기
import os 
import cv2
import matplotlib.pyplot as plt
import numpy as np
import dlib

home_dir = os.getenv('HOME')

my_image_path_a = os.path.join(home_dir, 'work/camera_sticker/images/choi.png')
my_image_path_b = os.path.join(home_dir, 'work/camera_sticker/images/choi_2.jpg')

img_bgr_a = cv2.imread(my_image_path_a)
img_bgr_b = cv2.imread(my_image_path_b)

img_show_a = img_bgr_a.copy()
img_show_b = img_bgr_b.copy()


plt.subplot(1, 2, 1)
plt.imshow(img_bgr_a)
plt.title("Front")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(img_bgr_b)
plt.title("Side")
plt.axis("off")

plt.show()

# %%
img_rgb_a = cv2.cvtColor(img_bgr_a, cv2.COLOR_BGR2RGB)
img_rgb_b = cv2.cvtColor(img_bgr_b, cv2.COLOR_BGR2RGB)

plt.subplot(1, 2, 1)
plt.imshow(img_rgb_a)
plt.title("Front")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(img_rgb_b)
plt.title("Side")
plt.axis("off")

plt.show()

# %%
detector_hog = dlib.get_frontal_face_detector()

# %%
img_rgb_pre_a = img_rgb_a
img_rgb_pre_b = img_rgb_b

dlib_rects_a = detector_hog(img_rgb_pre_a, 1)
dlib_rects_b = detector_hog(img_rgb_pre_b, 1) 
print("🌫🛸")
# Out:
# 🌫🛸

# %%
print(dlib_rects_a)
print(dlib_rects_b)

for dlib_rect in dlib_rects_a:
    l_a = dlib_rect.left()
    t_a = dlib_rect.top()
    r_a = dlib_rect.right()
    d_a = dlib_rect.bottom()

    cv2.rectangle(img_show_a, (l, t), (r, d), (0, 255, 0), 2, lineType=cv2.LINE_AA)

for dlib_rect in dlib_rects_b:
    l_a = dlib_rect.left()
    t_a = dlib_rect.top()
    r_a = dlib_rect.right()
    d_a = dlib_rect.bottom()

    cv2.rectangle(img_show_a, (l, t), (r, d), (0, 255, 0), 2, lineType=cv2.LINE_AA)

img_show_rgb = cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb)
plt.show()
# Out:
# rectangles[[(132, -89) (798, 650)]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 print(dlib_rects_a)
# ----> 2 print(dlib_rects_b)
#       4 for dlib_rect in dlib_rects:
#       5     l = dlib_rect.left()
#
# NameError: name 'dlib_rects_b' is not defined

# %%
# !wget http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# !mv shape_predictor_68_face_landmarks.dat.bz2 ~/work/camera_sticker/models

# %%
model_path = os.path.join(home_dir, 'work/camera_sticker/models/shape_predictor_68_face_landmarks.dat')
landmark_predictor = dlib.shape_predictor(model_path)
print("🌫🛸")
# Out:
# 🌫🛸

# %%
list_landmarks = []

for dlib_rect in dlib_rects:   #여기 왜 for문을? 검출된 모든 얼굴들의 bounding box 리스트이기 때문
    points = landmark_predictor(img_rgb, dlib_rect)
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

print(len(list_landmarks[0]))
# Out:
# 68

# %%
# 여러 개의 얼굴이 검출됐다는 가정하에 list_landmarks는 리스트 형태임
for landmark in list_landmarks:
    for point in landmark:
        cv2.circle(img_show, point, 2, (0, 255, 255), -1)

img_show_rgb = cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb)
plt.show()

# %%
# Step 3. 스티커 적용 위치 확인하기

# %%
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print(landmark[33]) # 코의 인덱스는 30
    x = landmark[33][0]
    y = landmark[33][1] + dlib_rect.height() // 2
    w = h = dlib_rect.width()

    print(f"(x,y) : ({x}, {y})")
    print(f"(w,h) : ({w}, {h})")
# Out:
# (157, 250)
# (x,y) : (157, 362)
# (w,h) : (224, 224)

# %%
# Step 4. 스티커 적용하기

# %%
sticker_path = os.path.join(home_dir, 'work/camera_sticker/images/cat-whiskers.png')
img_sticker = cv2.imread(sticker_path)
img_sticker = cv2.resize(img_sticker, (w, h))
print(img_sticker.shape)
# Out:
# (224, 224, 3)

# %%
refined_x = x - w // 2
refined_y = y - h

print(f'(x, y) : ({refined_x}, {refined_y})')
# Out:
# (x, y) : (45, 138)

# %%
# 이미지가 밖으로 시작하는 경우 예외처리
if refined_x < 0:
    img_sticker = img_sticker[:, -refined_x:]
    refined_x = 0

if refined_y < 0:
    img_sticker = img_sticker[-refined_y:, :]
    refined_y = 0

print(f"(x, y) : ({refined_x}, {refined_y})")
# Out:
# (x, y) : (45, 138)

# %%
sticker_area = img_show[refined_y:refined_y + img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]

img_show[refined_y:refined_y + img_sticker.shape[0], refined_x:refined_x + img_sticker.shape[1]] = np.where(img_sticker==255, sticker_area, img_sticker).astype(np.uint8)

print("슝슝")
# Out:
# 슝슝

# %%
plt.imshow(cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB))
plt.show()

# %%
sticker_area = img_bgr[refined_y:refined_y + img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_bgr[refined_y:refined_y + img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
np.where(img_sticker==255, sticker_area, img_sticker).astype(np.uint8)
plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.show()
