# %%
from utils import sticker_app
import os

home_dir = os.getenv('HOME')
my_image_path = os.path.join(home_dir, 'work/camera_sticker/images/choi_3.webp')
sticker_path = os.path.join(home_dir, 'work/camera_sticker/images/cat-whiskers.png')

sticker_app.sticker_attach(my_image_path, sticker_path)

# %%
from utils import sticker_app
import os

home_dir = os.getenv('HOME')
my_image_path = os.path.join(home_dir, 'work/camera_sticker/images/choi_2.jpg')
sticker_path = os.path.join(home_dir, 'work/camera_sticker/images/cat-whiskers.png')

sticker_app.sticker_attach(my_image_path, sticker_path)

# %%
from utils import sticker_app
import os

home_dir = os.getenv('HOME')
my_image_path = os.path.join(home_dir, 'work/camera_sticker/images/choi.png')
sticker_path = os.path.join(home_dir, 'work/camera_sticker/images/cat-whiskers.png')

sticker_app.sticker_attach(my_image_path, sticker_path)
